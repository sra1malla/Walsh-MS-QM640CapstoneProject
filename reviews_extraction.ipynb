# %%
import pandas as pd
import numpy as np
import traceback, logging
import datetime
import requests
import json

# %%
def extract_apps(lookup_file_path, store):
    try:
        app_lookup = pd.read_csv(lookup_file_path)
        apps = app_lookup[app_lookup['store'] == store]
        return apps
    except Exception as e:
        logging.error(traceback.format_exc())
        raise e

# %% [markdown]
# ## Google Play Store

# %%
lookup_file_path = './lookup/CompetitorApps_Lookup.csv'
store = 'Google Play Store'

gplay_apps = extract_apps(lookup_file_path, store)
gplay_apps
# Out:
#                 store application                 app_name  \
# 0   Google Play Store        ADCB                     ADCB
# 1   Google Play Store     Mashreq              Mashreq UAE
# 2   Google Play Store        ADIB  ADIB Mobile Banking App
# 3   Google Play Store        ENBD             Emirates NBD
# 4   Google Play Store         FAB               FAB Mobile
# 5   Google Play Store         DIB               DIB MOBILE
# 6   Google Play Store     SC Bank  SC Mobile Banking (UAE)
# 7   Google Play Store   Citi Bank             Citibank UAE
# 8   Google Play Store   HSBC Bank                 HSBC UAE
# 9   Google Play Store     RAKBANK              RAKBANK App
# 10  Google Play Store     EI Bank                  EI Bank
#
#                              app_id countries
# 0                     com.adcb.bank    ['ae']
# 1   com.vipera.ts.starter.MashreqAE    ['ae']
# 2                   com.adib.mobile    ['ae']
# 3                enbd.mobilebanking    ['ae']
# ...

# %%
df_gplay_reviews = pd.DataFrame()

# Review Extraction
gplay_apps = extract_apps(lookup_file_path, store)
for i in range(gplay_apps.shape[0]):
    store = gplay_apps.iloc[i, 0]
    app_name = gplay_apps.iloc[i, 1]
    app_id = gplay_apps.iloc[i, 3]
    print("Initiating reviews extraction for", store, " - ", app_name)
    total_pages = -1
    for i in range(1, 100):
#         print(i, total_pages)
        if i == total_pages + 1:
            break
        else:
            from_date = "2020-01-01"
            to_date = "2025-06-30"
            page = i
            url = f"https://api.appfollow.io/api/v2/reviews?ext_id={app_id}&from={from_date}&to={to_date}&page={page}"

            headers = {
                "accept": "application/json",
                "X-AppFollow-API-Token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJhcGl2MiIsInN1YiI6MjA3Nzc4LCJqdGkiOjM3NjQ4LCJzY29wZXMiOiJkcncifQ.PH5j33bFiQuc6Usc0rNYz2lpgFhUOmHBQ38napG8RvU"
            }

            response = requests.get(url, headers=headers)
            response.encoding = 'UTF-8'
            data = json.loads(response.text)
            if data['reviews']['total'] > 0:
                df = pd.json_normalize(data['reviews']['list'])
                total_pages = data['reviews']['page']['total']
            else:
                total_pages = 0
                print("No reviews available for", app_name)
                break

            if df.shape[0] > 0:
                df['store'] = store
                df['app_name'] = app_name
                df_gplay_reviews = pd.concat([df_gplay_reviews, df], ignore_index=True)
                df_gplay_reviews.reset_index(inplace=True, drop=True)
                print("Success - Appended ", df.shape[0], "reviews for", app_name)
            else:
                print("No reviews available for", app_name)
# Out:
# Initiating reviews extraction for Google Play -  ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# ...

# %%
print(df_gplay_reviews.shape)
df_gplay_reviews.head()
# Out:
# (58126, 34)
#                created                                        answer_text  \
# 0  2025-07-02 01:09:35  Sorry to hear you're having trouble with the a...
# 1  2025-07-01 22:05:23                                               None
# 2  2025-07-01 21:22:36  Hello, thank you for the encouraging star rati...
# 3  2025-07-01 19:10:27  Hello, thank you for the encouraging star rati...
# 4  2025-07-01 19:10:27  Sorry to hear you're having trouble with the a...
#
#   country user_id  has_answer  internal_id title app_version  \
# 0    None    None           1   6196067869              None
# 1    None    None           0   6196036641              None
# 2    None    None           1   6196020841              None
# 3    None    None           1   6195994899              None
# 4    None    None           1   6195994900              None
#
#                                              content answer_date  ...  \
# ...

# %%
df_gplay_reviews.columns
# Out:
# Index(['created', 'answer_text', 'country', 'user_id', 'has_answer',
#        'internal_id', 'title', 'app_version', 'content', 'answer_date',
#        'lang_detect', 'device_name', 'answer_time', 'is_deleted', 'author',
#        'was_changed', 'review_id', 'os', 'rating', 'time', 'device', 'date',
#        'updated', 'thumbs_up_cnt', 'store', 'app_version_code', 'is_answer',
#        'thumbs_down_cnt', 'device_type', 'manufactorer', 'lang',
#        'reviews_history', 'app_name', 'content_translated'],
#       dtype='object')

# %%
writer = pd.ExcelWriter("./extracts/gplay_reviews_2020-2025_raw.xlsx", engine='xlsxwriter')
df_gplay_reviews.to_excel(writer, encoding="utf-8-sig", index=False)
writer.save()

# %%
# Data Preprocessing
df_gplay_prcsd = df_gplay_reviews.copy()

df_gplay_prcsd['at_utc'] = pd.to_datetime(df_gplay_prcsd['date'].astype(str) + ' ' + df_gplay_prcsd['time'].astype(str), errors='coerce')
df_gplay_prcsd['at'] = df_gplay_prcsd['at_utc'].dt.tz_localize('UTC').dt.tz_convert('Asia/Dubai')
df_gplay_prcsd['at'] = df_gplay_prcsd['at'].dt.tz_localize(None)
df_gplay_prcsd['at_year'] = df_gplay_prcsd['at'].dt.year
df_gplay_prcsd['at_month'] = df_gplay_prcsd['at'].dt.month

df_gplay_prcsd['repliedAt_utc'] = pd.to_datetime(df_gplay_prcsd['answer_date'].astype(str) + ' ' + df_gplay_prcsd['answer_time'].astype(str), errors='coerce')
df_gplay_prcsd['repliedAt'] = df_gplay_prcsd['repliedAt_utc'].dt.tz_localize('UTC').dt.tz_convert('Asia/Dubai')
df_gplay_prcsd['repliedAt'] = df_gplay_prcsd['repliedAt'].dt.tz_localize(None)

df_gplay_prcsd = df_gplay_prcsd.drop(columns=[
    "updated", "time", "title", "is_answer", "device_name", "internal_id", "answer_date", "device",
    "was_changed", "os", "manufactorer", "device_type", "has_answer", "thumbs_up_cnt",
    "app_version_code", "lang_detect", "created", "is_deleted", "app_version", "answer_time",
    "thumbs_down_cnt", "user_id", "date"
])

df_gplay_prcsd = df_gplay_prcsd.rename(columns={
    "author": "userName",
    "answer_text": "replyContent",
    "lang": "language",
    "review_id": "reviewId",
    "content": "reviewContent",
    "at": "reviewedAt"
})

df_gplay_prcsd = df_gplay_prcsd[[
    "reviewId", "userName", "reviewContent", "rating", "reviewedAt", "replyContent", "repliedAt",
    "store", "app_name", "language", "at_year", "at_month", "country"
]]

print("Total Processed Reviews", df_gplay_prcsd.shape)
print(df_gplay_prcsd.shape)
# Out:
# Total Processed Reviews (58126, 13)
# (58126, 13)

# %%
writer = pd.ExcelWriter("./extracts/gplay_reviews_2020-2025_processed.xlsx", engine='xlsxwriter')
df_gplay_prcsd.to_excel(writer, encoding="utf-8-sig", index=False)
writer.save()

# %% [markdown]
# ## Apple App Store

# %%
lookup_file_path = './lookup/CompetitorApps_Lookup.csv'
store = 'Apple App Store'

apple_apps = extract_apps(lookup_file_path, store)
apple_apps
# Out:
#               store application                 app_name      app_id  \
# 11  Apple App Store        ADCB                     adcb   547172388
# 12  Apple App Store     Mashreq              mashreq-uae   378549193
# 13  Apple App Store        ADIB  adib-mobile-banking-app  1128180440
# 14  Apple App Store        ENBD             emirates-nbd   505092748
# 15  Apple App Store         FAB       fab-mobile-banking  1383237548
# 16  Apple App Store         DIB               dib-mobile   739758144
# 17  Apple App Store     SC Bank    sc-mobile-banking-uae   535729255
# 18  Apple App Store   Citi Bank             citibank-uae   415169488
# 19  Apple App Store   HSBC Bank                 hsbc-uae  1459836567
# 20  Apple App Store     RAKBANK              rakbank-app   427758991
# 21  Apple App Store     EI Bank                  ei-bank   516976912
#
#             countries
# 11   ['ae','in','us']
# 12   ['ae','in','us']
# 13   ['ae','in','us']
# 14   ['ae','in','us']
# ...

# %%
df_appstr_reviews = pd.DataFrame()

# Review Extraction
apple_apps = extract_apps(lookup_file_path, store)
for i in range(apple_apps.shape[0]):
    store = apple_apps.iloc[i, 0]
    app_name = apple_apps.iloc[i, 1]
    app_id = apple_apps.iloc[i, 3]
    print("Initiating reviews extraction for", store, " - ", app_name)
    total_pages = -1
    for i in range(1, 100):
#         print(i, total_pages)
        if i == total_pages + 1:
            break
        else:
            from_date = "2020-01-01"
            to_date = "2025-06-30"
            page = i
            url = f"https://api.appfollow.io/api/v2/reviews?ext_id={app_id}&from={from_date}&to={to_date}&page={page}"

            headers = {
                "accept": "application/json",
                "X-AppFollow-API-Token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJhcGl2MiIsInN1YiI6MjA3Nzc4LCJqdGkiOjM3NjQ4LCJzY29wZXMiOiJkcncifQ.PH5j33bFiQuc6Usc0rNYz2lpgFhUOmHBQ38napG8RvU"
            }

            response = requests.get(url, headers=headers)
            response.encoding = 'UTF-8'
            data = json.loads(response.text)
            if data['reviews']['total'] > 0:
                df = pd.json_normalize(data['reviews']['list'])
                total_pages = data['reviews']['page']['total']
            else:
                total_pages = 0
                print("No reviews available for", app_name)
                break

            if df.shape[0] > 0:
                df['store'] = store
                df['app_name'] = app_name
                df_appstr_reviews = pd.concat([df_appstr_reviews, df], ignore_index=True)
                df_appstr_reviews.reset_index(inplace=True, drop=True)
                print("Success - Appended ", df.shape[0], "reviews for", app_name)
            else:
                print("No reviews available for", app_name)
# Out:
# Initiating reviews extraction for Apple App Store  -  ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  100 reviews for ADCB
# Success - Appended  74 reviews for ADCB
# Initiating reviews extraction for Apple App Store  -  Mashreq
# Success - Appended  100 reviews for Mashreq
# Success - Appended  100 reviews for Mashreq
# Success - Appended  100 reviews for Mashreq
# Success - Appended  100 reviews for Mashreq
# ...

# %%
print(df_appstr_reviews.shape)
df_appstr_reviews.head()
# Out:
# (10753, 27)
#                                              content     user_id        date  \
# 0  For some reason I can't transfer money. It doe...   409498062  2025-06-30
# 1  The app was working good but from yesterday it...  1372263494  2025-06-28
# 2  This is very convenient mean time monthly amou...   564082753  2025-06-27
# 3  This application is convenient to use once you...  1508136639  2025-06-27
# 4  Cannot open my app for a 10 hours. I updated, ...  1802440987  2025-06-27
#
#    is_answer country  was_changed              updated answer_date  \
# 0          1      ae            0  2025-07-02 01:56:24  2025-07-17
# 1          1      ae            0  2025-06-29 19:38:51  2025-07-17
# 2          1      ae            0  2025-06-29 10:22:32  2025-07-17
# 3          0      ae            0  2025-06-29 10:22:32        None
# 4          1      ae            0  2025-06-29 10:22:32  2025-07-17
#
#    internal_id    review_id  ... rating  \
# 0    315565266  12833901269  ...      2
# ...

# %%
writer = pd.ExcelWriter("./extracts/appstr_reviews_2020-2025_raw.xlsx", engine='xlsxwriter')
df_appstr_reviews.to_excel(writer, encoding="utf-8-sig", index=False)
writer.save()

# %%
# Data Preprocessing
df_appstr_prcsd = df_appstr_reviews.copy()

df_appstr_prcsd['review_date_utc'] = pd.to_datetime(df_appstr_prcsd['date'].astype(str) + ' ' + df_appstr_prcsd['time'].astype(str), errors='coerce')
df_appstr_prcsd['review_date'] = df_appstr_prcsd['review_date_utc'].dt.tz_localize('UTC').dt.tz_convert('Asia/Dubai')
df_appstr_prcsd['review_date'] = df_appstr_prcsd['review_date'].dt.tz_localize(None)
df_appstr_prcsd['at_year'] = df_appstr_prcsd['review_date'].dt.year
df_appstr_prcsd['at_month'] = df_appstr_prcsd['review_date'].dt.month

df_appstr_prcsd['modified_utc'] = pd.to_datetime(df_appstr_prcsd['answer_date'].astype(str) + ' ' + df_appstr_prcsd['answer_time'].astype(str), errors='coerce')
df_appstr_prcsd['modified'] = df_appstr_prcsd['modified_utc'].dt.tz_localize('UTC').dt.tz_convert('Asia/Dubai')
df_appstr_prcsd['modified'] = df_appstr_prcsd['modified'].dt.tz_localize(None)

df_appstr_prcsd = df_appstr_prcsd.drop(columns=[
    "thumbs_up_cnt", "is_deleted", "thumbs_down_cnt", "user_id", "time", "created", "internal_id",
    "is_answer", "answer_date", "updated", "answer_time", "date", "app_version", "has_answer", "was_changed"
])

df_appstr_prcsd = df_appstr_prcsd.rename(columns={
    "review_id": "reviewId", "content": "reviewContent", "answer_text": "replyContent",
    "author": "userName", "review_date": "reviewedAt", "modified": "repliedAt", "lang_detect": "language"
})

df_appstr_prcsd = df_appstr_prcsd[[
    'reviewId', 'userName', 'reviewContent', 'rating', 'reviewedAt', 'replyContent', 'repliedAt',
    'store', 'app_name', 'language', 'at_year', 'at_month', 'country'
]]

print("Total Processed Reviews", df_appstr_prcsd.shape)
# Out:
# Total Processed Reviews (10753, 13)

# %%
writer = pd.ExcelWriter("./extracts/appstr_reviews_2020-2025_processed.xlsx", engine='xlsxwriter')
df_appstr_prcsd.to_excel(writer, encoding="utf-8-sig", index=False)
writer.save()

# %% [markdown]
# ## Merge Reviews

# %%
def merge_df(df1, df2):
    if np.array_equiv(df1.columns, df2.columns):
        df = pd.concat([df1, df2], axis=0)
        df.reset_index(inplace=True, drop=True)
        return df
    else:
        print("Error: Merge Failed! Check Dataframes and Columns")

# %%
df_merged = merge_df(df_gplay_prcsd, df_appstr_prcsd)
print("Total Reviews Merged:", df_merged.shape)

print("No Of Duplicates:", df_merged.duplicated(
    subset=['reviewId', 'userName', 'reviewContent', 'rating', 'reviewedAt', 'store']
).sum())

df_merged['res_ind'] = 0
df_merged.loc[df_merged.replyContent.isna(), 'res_ind'] = 1

df_merged['res_ind_rnk'] = df_merged.groupby(
    ['reviewId', 'userName', 'reviewContent', 'rating', 'reviewedAt', 'store'],
    dropna=False
)['res_ind'].transform('rank', method='first', ascending=True)

df_merged = df_merged[df_merged.res_ind_rnk == 1].copy().drop(columns=['res_ind_rnk', 'res_ind'])

print("Total Unique Reviews Merged:", df_merged.shape)
# Out:
# Total Reviews Merged: (68879, 13)
# No Of Duplicates: 0
# Total Unique Reviews Merged: (68879, 13)

# %%
writer = pd.ExcelWriter("./extracts/reviews_2020-2025_merged.xlsx", engine='xlsxwriter')
df_merged.to_excel(writer, encoding="utf-8-sig", index=False)
writer.save()

# %% [markdown]
# ## Sample Size Calculation

# %%
import pandas as pd

# Assuming df is your reviews dataframe and it has a 'rating' column
df_merged['sentiment'] = df_merged['rating'].apply(
    lambda x: 'positive' if x >= 4 else ('negative' if x <= 2 else 'neutral')
)

# To count each sentiment type
print(df_merged['sentiment'].value_counts())
# Out:
# positive    43288
# negative    23015
# neutral      2576
# Name: sentiment, dtype: int64

# %%
df_merged.head()
# Out:
#                                reviewId                       userName  \
# 0  a2393404-7755-4564-add7-b3029159bb71                   Farhat Taher
# 1  f521326b-0ffb-4620-8995-b04eeee01c8f                      Lee Kasim
# 2  6262b57b-7c21-4f6b-9a6a-b4fa8d60b395               ayasafputri love
# 3  1780c47d-38ad-4563-92c3-c381b717171f                   Ismail Momin
# 4  5083ac69-2298-45ee-9b96-1912e10dfed6  Abdullah Khalil fareh Almahri
#
#                                        reviewContent  rating  \
# 0  the application now for 4 days is not opening ...       1
# 1                                             normal       3
# 2                                               good       5
# 3                                     good thank you       5
# 4  Dear adcb bank i had a trouble on the Applicat...       5
#
#            reviewedAt                                       replyContent  \
# 0 2025-07-01 02:04:14  Sorry to hear you're having trouble with the a...
# ...

# %%
df_merged.columns
# Out:
# Index(['reviewId', 'userName', 'reviewContent', 'rating', 'reviewedAt',
#        'replyContent', 'repliedAt', 'store', 'app_name', 'language', 'at_year',
#        'at_month', 'country', 'sentiment'],
#       dtype='object')

# %%
df_merged[['reviewId', 'userName', 'reviewContent', 'rating', 'reviewedAt',
       'replyContent', 'repliedAt', 'store', 'app_name', 'language', 'country']].head()
# Out:
#                                reviewId                       userName  \
# 0  a2393404-7755-4564-add7-b3029159bb71                   Farhat Taher
# 1  f521326b-0ffb-4620-8995-b04eeee01c8f                      Lee Kasim
# 2  6262b57b-7c21-4f6b-9a6a-b4fa8d60b395               ayasafputri love
# 3  1780c47d-38ad-4563-92c3-c381b717171f                   Ismail Momin
# 4  5083ac69-2298-45ee-9b96-1912e10dfed6  Abdullah Khalil fareh Almahri
#
#                                        reviewContent  rating  \
# 0  the application now for 4 days is not opening ...       1
# 1                                             normal       3
# 2                                               good       5
# 3                                     good thank you       5
# 4  Dear adcb bank i had a trouble on the Applicat...       5
#
#            reviewedAt                                       replyContent  \
# 0 2025-07-01 02:04:14  Sorry to hear you're having trouble with the a...
# ...

# %%
df_merged['app_name'].unique()
# Out:
# array(['ADCB', 'Mashreq UAE', 'ADIB Mobile Banking App', 'Emirates NBD',
#        'FAB Mobile', 'DIB MOBILE', 'SC Mobile Banking (UAE)',
#        'Citibank UAE', 'HSBC UAE', 'RAKBANK App', 'EI Bank', 'Mashreq',
#        'ADIB', 'ENBD', 'FAB', 'DIB', 'SC Bank', 'Citi Bank', 'HSBC Bank',
#        'RAKBANK'], dtype=object)

# %%
from scipy.stats import norm
import math

# Parameters
alpha = 0.05
beta = 0.20
p1 = 0.80
p2 = 0.70
p_bar = (p1 + p2) / 2

z_alpha = norm.ppf(1 - alpha / 2)
z_beta = norm.ppf(1 - beta)

numerator = 2 * (z_alpha + z_beta)**2 * p_bar * (1 - p_bar)
denominator = (p1 - p2)**2

n_per_group = math.ceil(numerator / denominator)
n_total = 2 * n_per_group

print("Required per group:", n_per_group)
print("Total required:", n_total)
# Out:
# Required per group: 295
# Total required: 590
